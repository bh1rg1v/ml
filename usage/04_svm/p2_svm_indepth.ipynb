#        -9.3349675 , -9.29553652, -9.25483518, -9.21284664, -9.16955321,
#        -9.12493632, -9.07897646, -9.03165312, -8.98294476, -8.93282873,
#        -8.88128118, -8.82827705, -8.77378994, -8.71779204, -8.66025404])

# %%
x1 = np.linspace(-5, 5, 100)
y1 = np.sqrt(5**2 - x1**2)

x1 = np.hstack([x1, -x1])
y1 = np.hstack([y1, -y1])

# %%
plt.scatter(y, x)
plt.scatter(y1, x1)

# %%
np.vstack([y, x]).T
# Out:
# array([[ 8.66025404, -5.        ],
#        [ 8.71779204, -4.8989899 ],
#        [ 8.77378994, -4.7979798 ],
#        [ 8.82827705, -4.6969697 ],
#        [ 8.88128118, -4.5959596 ],
#        [ 8.93282873, -4.49494949],
#        [ 8.98294476, -4.39393939],
#        [ 9.03165312, -4.29292929],
#        [ 9.07897646, -4.19191919],
#        [ 9.12493632, -4.09090909],
#        [ 9.16955321, -3.98989899],
#        [ 9.21284664, -3.88888889],
#        [ 9.25483518, -3.78787879],
#        [ 9.29553652, -3.68686869],
#        [ 9.3349675 , -3.58585859],
#        [ 9.37314414, -3.48484848],
#        [ 9.41008171, -3.38383838],
#        [ 9.44579475, -3.28282828],
#        [ 9.4802971 , -3.18181818],
#        [ 9.51360192, -3.08080808],
#        [ 9.54572176, -2.97979798],
#        [ 9.57666854, -2.87878788],
#        [ 9.60645359, -2.77777778],
#        [ 9.63508769, -2.67676768],
#        [ 9.66258107, -2.57575758],
#        [ 9.68894344, -2.47474747],
#        [ 9.714184  , -2.37373737],
#        [ 9.73831149, -2.27272727],
#        [ 9.76133416, -2.17171717],
#        [ 9.7832598 , -2.07070707],
#        [ 9.80409577, -1.96969697],
#        [ 9.82384901, -1.86868687],
#        [ 9.84252604, -1.76767677],
#        [ 9.86013297, -1.66666667],
#        [ 9.87667553, -1.56565657],
#        [ 9.89215905, -1.46464646],
#        [ 9.90658851, -1.36363636],
#        [ 9.91996849, -1.26262626],
#        [ 9.93230325, -1.16161616],
#        [ 9.94359667, -1.06060606],
#        [ 9.9538523 , -0.95959596],
#        [ 9.96307334, -0.85858586],
#        [ 9.97126266, -0.75757576],
#        [ 9.9784228 , -0.65656566],
#        [ 9.98455598, -0.55555556],
#        [ 9.98966408, -0.45454545],
#        [ 9.99374868, -0.35353535],
#        [ 9.99681104, -0.25252525],
#        [ 9.99885209, -0.15151515],
#        [ 9.99987246, -0.05050505],
#        [ 9.99987246,  0.05050505],
#        [ 9.99885209,  0.15151515],
#        [ 9.99681104,  0.25252525],
#        [ 9.99374868,  0.35353535],
#        [ 9.98966408,  0.45454545],
#        [ 9.98455598,  0.55555556],
#        [ 9.9784228 ,  0.65656566],
#        [ 9.97126266,  0.75757576],
#        [ 9.96307334,  0.85858586],
#        [ 9.9538523 ,  0.95959596],
#        [ 9.94359667,  1.06060606],
#        [ 9.93230325,  1.16161616],
#        [ 9.91996849,  1.26262626],
#        [ 9.90658851,  1.36363636],
#        [ 9.89215905,  1.46464646],
#        [ 9.87667553,  1.56565657],
#        [-9.99681104,  0.25252525],
#        [-9.99885209,  0.15151515],
#        [-9.99987246,  0.05050505],
#        [-9.99987246, -0.05050505],
#        [-9.99885209, -0.15151515],
#        [-9.99681104, -0.25252525],
#        [-9.99374868, -0.35353535],
#        [-9.98966408, -0.45454545],
#        [-9.98455598, -0.55555556],
#        [-9.9784228 , -0.65656566],
#        [-9.97126266, -0.75757576],
#        [-9.96307334, -0.85858586],
#        [-9.9538523 , -0.95959596],
#        [-9.94359667, -1.06060606],
#        [-9.93230325, -1.16161616],
#        [-9.91996849, -1.26262626],
#        [-9.90658851, -1.36363636],
#        [-9.89215905, -1.46464646],
#        [-9.87667553, -1.56565657],
#        [-9.86013297, -1.66666667],
#        [-9.84252604, -1.76767677],
#        [-9.82384901, -1.86868687],
#        [-9.80409577, -1.96969697],
#        [-9.7832598 , -2.07070707],
#        [-9.76133416, -2.17171717],
#        [-9.73831149, -2.27272727],
#        [-9.714184  , -2.37373737],
#        [-9.68894344, -2.47474747],
#        [-9.66258107, -2.57575758],
#        [-9.63508769, -2.67676768],
#        [-9.60645359, -2.77777778],
#        [-9.57666854, -2.87878788],
#        [-9.54572176, -2.97979798],
#        [-9.51360192, -3.08080808],
#        [-9.4802971 , -3.18181818],
#        [-9.44579475, -3.28282828],
#        [-9.41008171, -3.38383838],
#        [-9.37314414, -3.48484848],
#        [-9.3349675 , -3.58585859],
#        [-9.29553652, -3.68686869],
#        [-9.25483518, -3.78787879],
#        [-9.21284664, -3.88888889],
#        [-9.16955321, -3.98989899],
#        [-9.12493632, -4.09090909],
#        [-9.07897646, -4.19191919],
#        [-9.03165312, -4.29292929],
#        [-8.98294476, -4.39393939],
#        [-8.93282873, -4.49494949],
#        [-8.88128118, -4.5959596 ],
#        [-8.82827705, -4.6969697 ],
#        [-8.77378994, -4.7979798 ],
#        [-8.71779204, -4.8989899 ],
#        [-8.66025404, -5.        ]])

# %%
df1 = pd.DataFrame(np.vstack([y, x]).T, columns=["x1", "x2"])
df1["y"] = 0

df2 = pd.DataFrame(np.vstack([y1, x1]).T, columns=["x1", "x2"])
df2["y"] = 1

df = pd.concat([df1, df2], ignore_index=True)

df.head(5)
# Out:
#          x1       x2  y
# 0  8.660254 -5.00000  0
# 1  8.717792 -4.89899  0
# 2  8.773790 -4.79798  0
# 3  8.828277 -4.69697  0
# 4  8.881281 -4.59596  0

# %%
df.tail()
# Out:
#            x1       x2  y
# 395 -1.969049 -4.59596  1
# 396 -1.714198 -4.69697  1
# 397 -1.406908 -4.79798  1
# 398 -0.999949 -4.89899  1
# 399 -0.000000 -5.00000  1

# %%
# defining and independent and dependent features

x = df.iloc[:, :2]
y = df.y

# %%
x
# Out:
#            x1       x2
# 0    8.660254 -5.00000
# 1    8.717792 -4.89899
# 2    8.773790 -4.79798
# 3    8.828277 -4.69697
# 4    8.881281 -4.59596
# ..        ...      ...
# 395 -1.969049 -4.59596
# 396 -1.714198 -4.69697
# 397 -1.406908 -4.79798
# 398 -0.999949 -4.89899
# 399 -0.000000 -5.00000
#
# [400 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    1
# 399    1
# Name: y, Length: 400, dtype: int64

# %%
# train test split

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
y_train
# Out:
# 250    1
# 63     0
# 312    1
# 159    0
# 283    1
#       ..
# 323    1
# 192    0
# 117    0
# 47     0
# 172    0
# Name: y, Length: 300, dtype: int64

# %%
# we have to find components for the polynomial kernel

# x1, x2, x1_square, x2_square, x1 * x2

df["x1_square"] = df["x1"] ** 2
df["x2_square"] = df["x2"] ** 2
df["x1*x2"] = df["x1"] ** df["x2"]

df.head()
# Out:
#          x1       x2  y  x1_square  x2_square     x1*x2
# 0  8.660254 -5.00000  0  75.000000  25.000000  0.000021
# 1  8.717792 -4.89899  0  75.999898  24.000102  0.000025
# 2  8.773790 -4.79798  0  76.979390  23.020610  0.000030
# 3  8.828277 -4.69697  0  77.938476  22.061524  0.000036
# 4  8.881281 -4.59596  0  78.877155  21.122845  0.000044

# %%
# defining independent and dependent features

x = df[["x1", "x2", "x1_square", "x2_square", "x1*x2"]]
y = df["y"]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    1
# 399    1
# Name: y, Length: 400, dtype: int64

# %%
x
# Out:
#            x1       x2  x1_square  x2_square     x1*x2
# 0    8.660254 -5.00000  75.000000  25.000000  0.000021
# 1    8.717792 -4.89899  75.999898  24.000102  0.000025
# 2    8.773790 -4.79798  76.979390  23.020610  0.000030
# 3    8.828277 -4.69697  77.938476  22.061524  0.000036
# 4    8.881281 -4.59596  78.877155  21.122845  0.000044
# ..        ...      ...        ...        ...       ...
# 395 -1.969049 -4.59596   3.877155  21.122845       NaN
# 396 -1.714198 -4.69697   2.938476  22.061524       NaN
# 397 -1.406908 -4.79798   1.979390  23.020610       NaN
# 398 -0.999949 -4.89899   0.999898  24.000102       NaN
# 399 -0.000000 -5.00000   0.000000  25.000000      -inf
#
# [400 rows x 5 columns]

# %%
# train test split

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
x_train
# Out:
#            x1        x2  x1_square  x2_square      x1*x2
# 250  4.999745  0.050505  24.997449   0.002551   1.084677
# 63   9.906589  1.363636  98.140496   1.859504  22.807535
# 312 -3.263736  3.787879  10.651974  14.348026        NaN
# 159 -9.953852 -0.959596  99.079176   0.920824        NaN
# 283  3.680983  3.383838  13.549638  11.450362  82.248915
# ..        ...       ...        ...        ...        ...
# 323 -4.223140  2.676768  17.834915   7.165085        NaN
# 192 -9.031653 -4.292929  81.570758  18.429242        NaN
# 117 -9.445795  3.282828  89.223038  10.776962        NaN
# 47   9.996811 -0.252525  99.936231   0.063769   0.559126
# 172 -9.738311 -2.272727  94.834711   5.165289        NaN
#
# [300 rows x 5 columns]

# %%
x_test
# Out:
#            x1        x2  x1_square  x2_square     x1*x2
# 132 -9.842526  1.767677  96.875319   3.124681       NaN
# 309 -2.874798  4.090909   8.264463  16.735537       NaN
# 341 -4.925731  0.858586  24.262830   0.737170       NaN
# 196 -8.828277 -4.696970  77.938476  22.061524       NaN
# 246  4.987486 -0.353535  24.875013   0.124987  0.566597
# ..        ...       ...        ...        ...       ...
# 146 -9.993749  0.353535  99.875013   0.124987       NaN
# 135 -9.892159  1.464646  97.854811   2.145189       NaN
# 390 -2.874798 -4.090909   8.264463  16.735537       NaN
# 264  4.780671  1.464646  22.854811   2.145189  9.890332
# 364 -4.780671 -1.464646  22.854811   2.145189       NaN
#
# [100 rows x 5 columns]

# %%
import plotly.express as px

fig = px.scatter_3d(df, x="x1", y="x2", z="x1*x2", color="y")

fig.show()

# %%
fig = px.scatter_3d(df, x="x1_square", y="x2_square", z="x1*x2", color="y")

fig.show()

# %%
pd.DataFrame(x_train).isna().sum()
# Out:
# x1             0
# x2             0
# x1_square      0
# x2_square      0
# x1*x2        146
# dtype: int64

# %%
df = df.dropna()

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")

x_train = pd.DataFrame(x_train).replace([np.inf, -np.inf], np.nan)
x_test = pd.DataFrame(x_test).replace([np.inf, -np.inf], np.nan)

x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

model = SVC(kernel="linear")

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        55
#            1       1.00      1.00      1.00        45
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# [[55  0]
#  [ 0 45]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

model = SVC(kernel="poly")

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.46
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.04        55
#            1       0.45      1.00      0.62        45
#
#     accuracy                           0.46       100
#    macro avg       0.73      0.51      0.33       100
# weighted avg       0.75      0.46      0.30       100
#
# [[ 1 54]
#  [ 0 45]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

model = SVC(kernel="rbf")

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.48
#               precision    recall  f1-score   support
#
#            0       0.53      0.51      0.52        55
#            1       0.43      0.44      0.43        45
#
#     accuracy                           0.48       100
#    macro avg       0.48      0.48      0.48       100
# weighted avg       0.48      0.48      0.48       100
#
# [[28 27]
#  [25 20]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

model = SVC(kernel="sigmoid")

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55        55
#            1       0.44      0.44      0.44        45
#
#     accuracy                           0.50       100
#    macro avg       0.49      0.49      0.49       100
# weighted avg       0.50      0.50      0.50       100
#
# [[30 25]
#  [25 20]]
